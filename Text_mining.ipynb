# %% [markdown]
# ## Processing data

# %%
import pandas as pd
reviews = pd.read_parquet("reviews2.parquet", columns = ["review_id", "business_id", "user_id", "stars", "text", "date"])  # cleaned version
business = pd.read_parquet("business.parquet")  # changed cleaner version to parquet in earlier file.
users = pd.read_parquet("users2.parquet", columns = ["user_id", "name", "review_count","yelping_since"])  # unchanged.

# %%
merged_df = reviews.merge(users, on='user_id', how='left', suffixes = ['_review', '_user'])
merged_df_numeric = merged_df.drop(columns=['review_id', 'user_id', 'business_id', 'text', 'name', 
                                         'yelping_since', 'date'])
merged_df_numeric = merged_df_numeric.dropna()

# %%
merged_df['text']

# %%
#lower text
df_text = pd.DataFrame(merged_df.text.str.lower())
df_text = df_text.sample(10000, random_state=42)

# %% [markdown]
# ## Cleaning text

# %% [markdown]
# ### Tokenization: Text to Tokens

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.67.1)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.casual import TweetTokenizer
import string
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize, sent_tokenize, WhitespaceTokenizer, RegexpTokenizer
from nltk.corpus import words
from nltk.tokenize import SyllableTokenizer

# download package
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('words')

# upload stopwords and string
punctuations = set(string.punctuation)
english_words = set(words.words())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jupyter/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package words to /home/jupyter/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
tokenized = [word_tokenize(t) for t in df_text['text']] 
tokenized[0]
# Out:
# ['ok',
#  ',',
#  'let',
#  'me',
#  'start',
#  'off',
#  'by',
#  'acknowledging',
#  'i',
#  'know',
#  'how',
#  'stressful',
#  'restaurant',
#  'week',
#  'is',
#  'for',
#  'servers',
#  'who',
#  'are',
#  'underpaid',
#  'and',
#  'overworked',
#  '.',
#  'my',
#  'experience',
#  'last',
#  'night',
#  'was',
#  'absolutely',
#  'incredible',
#  '.',
#  'we',
#  'made',
#  'reservations',
#  'on',
#  'open',
#  'table',
#  'for',
#  '8',
#  "o'clock",
#  'for',
#  'the',
#  'restaurant',
#  'week',
#  'special',
#  '.',
#  'we',
#  'were',
#  'offered',
#  'inside',
#  'or',
#  'outside',
#  'seating',
#  'and',
#  'opted',
#  'for',
#  'the',
#  'latter',
#  '.',
#  'the',
#  "'porch",
#  "'",
#  'set',
#  'the',
#  'tone',
#  'for',
#  'a',
#  'wonderful',
#  'experience',
#  '-',
#  'think',
#  'southern',
#  'wraparound',
#  'porch',
#  'with',
#  'an',
#  'aesthetically',
#  'pleasing',
#  'faux',
#  'ivy',
#  'wall',
#  'and',
#  'high',
#  'top',
#  'seating',
#  '.',
#  'the',
#  'perfect',
#  'spot',
#  'for',
#  'a',
#  'afternoon',
#  'cocktail',
#  'in',
#  'the',
#  'summer',
#  '!',
#  'our',
#  'server',
#  '(',
#  'wish',
#  'i',
#  'remembered',
#  'his',
#  'name',
#  ',',
#  'he',
#  'was',
#  'excellent',
#  ')',
#  'almost',
#  'immediately',
#  'acknowledged',
#  'and',
#  'picked',
#  'up',
#  'our',
#  'drink',
#  'orders',
#  '-',
#  'both',
#  'queen',
#  'anne',
#  "'s",
#  'revenge',
#  ',',
#  'their',
#  'twist',
#  'on',
#  'an',
#  'old',
#  'fashion',
#  '.',
#  'this',
#  'drink',
#  'is',
#  'not',
#  'for',
#  'the',
#  'faint',
#  'of',
#  'heart',
#  'and',
#  'thankfully',
#  'we',
#  'both',
#  'needed',
#  'a',
#  'stiff',
#  'drink',
#  '.',
#  'for',
#  'our',
#  'first',
#  'course',
#  'we',
#  'had',
#  'fried',
#  'green',
#  'tomatoes',
#  ',',
#  'and',
#  'crushpuppies',
#  '.',
#  'fried',
#  'green',
#  'tomatoes',
#  ',',
#  'had',
#  'a',
#  'delicious',
#  'remoulade',
#  'and',
#  'a',
#  'little',
#  'pickled',
#  'shrimp',
#  'right',
#  'on',
#  'top',
#  '.',
#  'crushpuppies',
#  'had',
#  'this',
#  'yummy',
#  'sweet',
#  'and',
#  'savory',
#  'combination',
#  'that',
#  'allowed',
#  'the',
#  'sweet',
#  'buttery',
#  'cornbread',
#  'paired',
#  'really',
#  'well',
#  'with',
#  'the',
#  'crunchy',
#  'outer',
#  'shell',
#  '.',
#  'up',
#  'next',
#  'the',
#  'second',
#  'course',
#  ',',
#  'he',
#  'had',
#  'the',
#  "'she-crab",
#  "'",
#  'soup',
#  ',',
#  'and',
#  'i',
#  'had',
#  'the',
#  'watermelon',
#  'salad',
#  '.',
#  'we',
#  "'re",
#  'accustomed',
#  'to',
#  'the',
#  'she',
#  'crab',
#  'soup',
#  'from',
#  'down',
#  'the',
#  'shore',
#  'and',
#  'i',
#  'was',
#  'a',
#  'little',
#  'nervous',
#  'it',
#  'would',
#  "n't",
#  'meet',
#  'our',
#  'standards',
#  '.',
#  'both',
#  'the',
#  'soup',
#  'and',
#  'the',
#  'salad',
#  'exceeded',
#  'expectations',
#  '.',
#  'soup',
#  'came',
#  'in',
#  'a',
#  'hearty',
#  ',',
#  'almost',
#  'overwhelming',
#  'bowl',
#  '.',
#  'salad',
#  'had',
#  'a',
#  'beautiful',
#  'presentation',
#  'and',
#  'this',
#  'amazing',
#  'sweet',
#  'and',
#  'juicy',
#  'watermelon',
#  '.',
#  'at',
#  'this',
#  'point',
#  '-',
#  'i',
#  "'m",
#  'raving',
#  'about',
#  'how',
#  'much',
#  'i',
#  'want',
#  'to',
#  'come',
#  'back',
#  ',',
#  'even',
#  'sent',
#  'a',
#  'group',
#  'text',
#  'to',
#  'my',
#  'family',
#  'letting',
#  'them',
#  'know',
#  'they',
#  'have',
#  'to',
#  'try',
#  'this',
#  'place',
#  '.',
#  'we',
#  'receive',
#  'our',
#  'entrees',
#  'and',
#  'and',
#  'i',
#  'knew',
#  'from',
#  'that',
#  'point',
#  'forward',
#  'this',
#  'would',
#  'be',
#  'my',
#  'little',
#  'gem',
#  'in',
#  'old',
#  'city',
#  '.',
#  'i',
#  'had',
#  'the',
#  'short',
#  'rib',
#  ',',
#  'he',
#  'had',
#  'the',
#  'red',
#  'snapper',
#  '.',
#  'short',
#  'rib',
#  'is',
#  'bone',
#  'in',
#  'and',
#  'had',
#  'these',
#  'mouthwatering',
#  'cheesy',
#  'grits',
#  'in',
#  'a',
#  'flavorful',
#  'stew',
#  '.',
#  'just',
#  'when',
#  'i',
#  'think',
#  'it',
#  'ca',
#  "n't",
#  'get',
#  'any',
#  'better',
#  ',',
#  'i',
#  'pull',
#  'up',
#  'a',
#  'spoonful',
#  'of',
#  'okra',
#  '.',
#  'okra',
#  'is',
#  'one',
#  'of',
#  'my',
#  'absolute',
#  'favorites',
#  'and',
#  'brings',
#  'back',
#  'so',
#  'many',
#  'memories',
#  'of',
#  'my',
#  'grandmothers',
#  'home',
#  'cooking',
#  '-',
#  'but',
#  'its',
#  'rare',
#  ',',
#  'especially',
#  'in',
#  'the',
#  'city',
#  ',',
#  'to',
#  'find',
#  'it',
#  'cooked',
#  'correctly',
#  '.',
#  'finally',
#  'we',
#  'finished',
#  'off',
#  'our',
#  'meets',
#  'with',
#  'another',
#  'round',
#  'of',
#  'cocktails',
#  '&',
#  'dessert',
#  '.',
#  'i',
#  'definitely',
#  'recommend',
#  'the',
#  'kentucky',
#  'mule',
#  '(',
#  'whiskey',
#  'mule',
#  '-',
#  'very',
#  'refreshing',
#  ')',
#  'and',
#  'the',
#  'east',
#  'bay',
#  'old',
#  'fashion',
#  '(',
#  'whiskey',
#  'sour',
#  ')',
#  '.',
#  'now',
#  ',',
#  'i',
#  "'m",
#  'not',
#  'typically',
#  'a',
#  'donut',
#  'fan',
#  '...',
#  'but',
#  'these',
#  'ricotta',
#  'donuts',
#  '...',
#  'changed',
#  'my',
#  'opinion',
#  'on',
#  'that',
#  ',',
#  'these',
#  'were',
#  'super',
#  'doughy',
#  'and',
#  'dense',
#  'almost',
#  'like',
#  'a',
#  'cake',
#  'with',
#  'this',
#  'creamy',
#  'kahlua',
#  'glaze',
#  'and',
#  'berry',
#  'spread',
#  '.',
#  'wow',
#  '!',
#  'honestly',
#  ',',
#  'if',
#  'your',
#  'in',
#  'the',
#  'area',
#  'stop',
#  'by',
#  'and',
#  'check',
#  'it',
#  'out',
#  'definitely',
#  'worth',
#  'it',
#  'even',
#  'if',
#  'your',
#  'just',
#  'checking',
#  'out',
#  'the',
#  'patio',
#  '.']

# %% [markdown]
# ### Stopword + punctuations

# %%
import string
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
punctuations = set(string.punctuation)
tokenized_filtered = [[word for word in sentence if word.lower() not in stop_words and word not in punctuations] for sentence in tokenized]

print(tokenized_filtered[0])
# Out:
# ['ok', 'let', 'start', 'acknowledging', 'know', 'stressful', 'restaurant', 'week', 'servers', 'underpaid', 'overworked', 'experience', 'last', 'night', 'absolutely', 'incredible', 'made', 'reservations', 'open', 'table', '8', "o'clock", 'restaurant', 'week', 'special', 'offered', 'inside', 'outside', 'seating', 'opted', 'latter', "'porch", 'set', 'tone', 'wonderful', 'experience', 'think', 'southern', 'wraparound', 'porch', 'aesthetically', 'pleasing', 'faux', 'ivy', 'wall', 'high', 'top', 'seating', 'perfect', 'spot', 'afternoon', 'cocktail', 'summer', 'server', 'wish', 'remembered', 'name', 'excellent', 'almost', 'immediately', 'acknowledged', 'picked', 'drink', 'orders', 'queen', 'anne', "'s", 'revenge', 'twist', 'old', 'fashion', 'drink', 'faint', 'heart', 'thankfully', 'needed', 'stiff', 'drink', 'first', 'course', 'fried', 'green', 'tomatoes', 'crushpuppies', 'fried', 'green', 'tomatoes', 'delicious', 'remoulade', 'little', 'pickled', 'shrimp', 'right', 'top', 'crushpuppies', 'yummy', 'sweet', 'savory', 'combination', 'allowed', 'sweet', 'buttery', 'cornbread', 'paired', 'really', 'well', 'crunchy', 'outer', 'shell', 'next', 'second', 'course', "'she-crab", 'soup', 'watermelon', 'salad', "'re", 'accustomed', 'crab', 'soup', 'shore', 'little', 'nervous', 'would', "n't", 'meet', 'standards', 'soup', 'salad', 'exceeded', 'expectations', 'soup', 'came', 'hearty', 'almost', 'overwhelming', 'bowl', 'salad', 'beautiful', 'presentation', 'amazing', 'sweet', 'juicy', 'watermelon', 'point', "'m", 'raving', 'much', 'want', 'come', 'back', 'even', 'sent', 'group', 'text', 'family', 'letting', 'know', 'try', 'place', 'receive', 'entrees', 'knew', 'point', 'forward', 'would', 'little', 'gem', 'old', 'city', 'short', 'rib', 'red', 'snapper', 'short', 'rib', 'bone', 'mouthwatering', 'cheesy', 'grits', 'flavorful', 'stew', 'think', 'ca', "n't", 'get', 'better', 'pull', 'spoonful', 'okra', 'okra', 'one', 'absolute', 'favorites', 'brings', 'back', 'many', 'memories', 'grandmothers', 'home', 'cooking', 'rare', 'especially', 'city', 'find', 'cooked', 'correctly', 'finally', 'finished', 'meets', 'another', 'round', 'cocktails', 'dessert', 'definitely', 'recommend', 'kentucky', 'mule', 'whiskey', 'mule', 'refreshing', 'east', 'bay', 'old', 'fashion', 'whiskey', 'sour', "'m", 'typically', 'donut', 'fan', '...', 'ricotta', 'donuts', '...', 'changed', 'opinion', 'super', 'doughy', 'dense', 'almost', 'like', 'cake', 'creamy', 'kahlua', 'glaze', 'berry', 'spread', 'wow', 'honestly', 'area', 'stop', 'check', 'definitely', 'worth', 'even', 'checking', 'patio']

# %% [markdown]
# ### merge back

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()  

tokenized_filtered_stemmed = []
for tokenized_sentence in tokenized_filtered: 
    tokenized_filtered_stemmed.append([ps.stem(word) for word in tokenized_sentence])

tokenized_filtered_stemmed[0:1]
# Out:
# [['ok',
#   'let',
#   'start',
#   'acknowledg',
#   'know',
#   'stress',
#   'restaur',
#   'week',
#   'server',
#   'underpaid',
#   'overwork',
#   'experi',
#   'last',
#   'night',
#   'absolut',
#   'incred',
#   'made',
#   'reserv',
#   'open',
#   'tabl',
#   '8',
#   "o'clock",
#   'restaur',
#   'week',
#   'special',
#   'offer',
#   'insid',
#   'outsid',
#   'seat',
#   'opt',
#   'latter',
#   "'porch",
#   'set',
#   'tone',
#   'wonder',
#   'experi',
#   'think',
#   'southern',
#   'wraparound',
#   'porch',
#   'aesthet',
#   'pleas',
#   'faux',
#   'ivi',
#   'wall',
#   'high',
#   'top',
#   'seat',
#   'perfect',
#   'spot',
#   'afternoon',
#   'cocktail',
#   'summer',
#   'server',
#   'wish',
#   'rememb',
#   'name',
#   'excel',
#   'almost',
#   'immedi',
#   'acknowledg',
#   'pick',
#   'drink',
#   'order',
#   'queen',
#   'ann',
#   "'s",
#   'reveng',
#   'twist',
#   'old',
#   'fashion',
#   'drink',
#   'faint',
#   'heart',
#   'thank',
#   'need',
#   'stiff',
#   'drink',
#   'first',
#   'cours',
#   'fri',
#   'green',
#   'tomato',
#   'crushpuppi',
#   'fri',
#   'green',
#   'tomato',
#   'delici',
#   'remoulad',
#   'littl',
#   'pickl',
#   'shrimp',
#   'right',
#   'top',
#   'crushpuppi',
#   'yummi',
#   'sweet',
#   'savori',
#   'combin',
#   'allow',
#   'sweet',
#   'butteri',
#   'cornbread',
#   'pair',
#   'realli',
#   'well',
#   'crunchi',
#   'outer',
#   'shell',
#   'next',
#   'second',
#   'cours',
#   "'she-crab",
#   'soup',
#   'watermelon',
#   'salad',
#   "'re",
#   'accustom',
#   'crab',
#   'soup',
#   'shore',
#   'littl',
#   'nervou',
#   'would',
#   "n't",
#   'meet',
#   'standard',
#   'soup',
#   'salad',
#   'exceed',
#   'expect',
#   'soup',
#   'came',
#   'hearti',
#   'almost',
#   'overwhelm',
#   'bowl',
#   'salad',
#   'beauti',
#   'present',
#   'amaz',
#   'sweet',
#   'juici',
#   'watermelon',
#   'point',
#   "'m",
#   'rave',
#   'much',
#   'want',
#   'come',
#   'back',
#   'even',
#   'sent',
#   'group',
#   'text',
#   'famili',
#   'let',
#   'know',
#   'tri',
#   'place',
#   'receiv',
#   'entre',
#   'knew',
#   'point',
#   'forward',
#   'would',
#   'littl',
#   'gem',
#   'old',
#   'citi',
#   'short',
#   'rib',
#   'red',
#   'snapper',
#   'short',
#   'rib',
#   'bone',
#   'mouthwat',
#   'cheesi',
#   'grit',
#   'flavor',
#   'stew',
#   'think',
#   'ca',
#   "n't",
#   'get',
#   'better',
#   'pull',
#   'spoon',
#   'okra',
#   'okra',
#   'one',
#   'absolut',
#   'favorit',
#   'bring',
#   'back',
#   'mani',
#   'memori',
#   'grandmoth',
#   'home',
#   'cook',
#   'rare',
#   'especi',
#   'citi',
#   'find',
#   'cook',
#   'correctli',
#   'final',
#   'finish',
#   'meet',
#   'anoth',
#   'round',
#   'cocktail',
#   'dessert',
#   'definit',
#   'recommend',
#   'kentucki',
#   'mule',
#   'whiskey',
#   'mule',
#   'refresh',
#   'east',
#   'bay',
#   'old',
#   'fashion',
#   'whiskey',
#   'sour',
#   "'m",
#   'typic',
#   'donut',
#   'fan',
#   '...',
#   'ricotta',
#   'donut',
#   '...',
#   'chang',
#   'opinion',
#   'super',
#   'doughi',
#   'dens',
#   'almost',
#   'like',
#   'cake',
#   'creami',
#   'kahlua',
#   'glaze',
#   'berri',
#   'spread',
#   'wow',
#   'honestli',
#   'area',
#   'stop',
#   'check',
#   'definit',
#   'worth',
#   'even',
#   'check',
#   'patio']]

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer

for tokenized_sentence in tokenized_filtered_stemmed:
   print(TreebankWordDetokenizer().detokenize(tokenized_sentence))
# Out:
# ok let start acknowledg know stress restaur week server underpaid overwork experi last night absolut incred made reserv open tabl 8 o'clock restaur week special offer insid outsid seat opt latter 'porch set tone wonder experi think southern wraparound porch aesthet pleas faux ivi wall high top seat perfect spot afternoon cocktail summer server wish rememb name excel almost immedi acknowledg pick drink order queen ann's reveng twist old fashion drink faint heart thank need stiff drink first cours fri green tomato crushpuppi fri green tomato delici remoulad littl pickl shrimp right top crushpuppi yummi sweet savori combin allow sweet butteri cornbread pair realli well crunchi outer shell next second cours 'she-crab soup watermelon salad're accustom crab soup shore littl nervou wouldn't meet standard soup salad exceed expect soup came hearti almost overwhelm bowl salad beauti present amaz sweet juici watermelon point'm rave much want come back even sent group text famili let know tri place receiv entre knew point forward would littl gem old citi short rib red snapper short rib bone mouthwat cheesi grit flavor stew think can't get better pull spoon okra okra one absolut favorit bring back mani memori grandmoth home cook rare especi citi find cook correctli final finish meet anoth round cocktail dessert definit recommend kentucki mule whiskey mule refresh east bay old fashion whiskey sour'm typic donut fan...ricotta donut...chang opinion super doughi dens almost like cake creami kahlua glaze berri spread wow honestli area stop check definit worth even check patio
# awesom servic heather great person special drink good craft beer food uniqu fill downtown st. petersburg stop even drink
# bring car charg 1000 air condition repair left air filter rip intak valv person complet repair extrem racist never returnn't either contact corpor lodg offici complaint
# new favorit pizza place indianapoli made hous gluten free crust best hand great servic great vibe
# great place ice cream purchas meat well's even better serv ice cream
# local compani excel custom servic knowledg price servic great would certainli recommend work residenti commerci industri
# wreck chees salt sound like furthest wish palett travel thoroughli enjoy ramano's rest us disappoint menu
# super cute place walk got sat immedi waiter toni amaz gave us ton recommend place amaz got bbq shrimp grit sooo delici
# belgian cafe definit deserv respect prop previou review sunday treat parent mid day lunch splurg numer thing menu bosch mussel pomm frite chicken salad smoke turkey chees steak special got egg benedict start bosch mussel simpli amaz parent rant rave mussel past new england tast...word couldn't describ express face much like pomm frite dip sauc tasti alway salad great alway smoke turkey special wonder final egg benedict top belgium waffl d-d-delici normal would gotten beer go along time howev make recommend would tri "petru age pale" tri monk stimul hook three us splurg bill bad previou review said kinda pricey total take back 7 star
# n't wings-to-go year popular franchis feel's gone away nice locat probabl best franchis ever seen food
# purchas new 2021 jeep grand cheroke loredo super satisfi car schedul appoint onlin lindsay dattilio abl get us exactli want super friendli provid excel servic staff super friendli definit refer famili friend
# tri extra fanci gnocchi huge fan one best prepar pasta product hope next time'm philli manag stop place pasta list seriou devote high qualiti pasta product
# tasti fresh food small portion atmospher lack dirti front door confus order process...stilln't understand order soup salad front line husband order mid line salad made front us soup salad materin't know anyway end food time wait coupl minut food arriv food fresh tasti squash soup bit sweet tast still good like choic would go back
# terribl suppos pickup trash recycl day labor day sinc monday holiday state websit pickup day fall holiday come next day well noth pick last tuesday .... wednesday thank good twice week pickup trash pick trash thursday ..... .... recycl sat curb end week today week labor day everyth back schedul right well came home work recycl pick know 2 week box can magazin newspap bottl look like hous 4 2 dog cat unsatisfi custom .... one mani problem experienc republ year ago use trash/recycl unhappi switch leck truli best republ bought leck residenti year ago saddest day everyon develop
# n't even know begin favorit part last week one besti celebr end extra arduou month school amaz food vibe cute definit romant want date --'d perfect probabl one date oyster delici'm typic oyster person appet also got black bass look beauti tast great order tuna friend order monk fish sauc monk fish probabl bit better tuna cook perfect overal delici full meal start finish enjoy definit recommend albeitn't usual post review'm big foodi gone top restaur philli throughout last 5 year
# pretti amaz cathedr've seen mani cathedr ornat fresca paint world mosaic glass quit impress 41.5 million piec glass adorn wall ceil ...'s hard imagin's vibrant awe struck walk ad stare mosaic art's museum downstair show histori great place visit st. loui
# love place've everi month sinc start come 5 year ago've almost everyth hot wing greek salad chop salad rice black bean steak etc man love place sinc introduc zeko's alway say eat zeko's 's vegetarian love fish grill black bean rice chop salad'm eat steak chees sub today keep great job zeko went zeko last night 6/28/19 daughter best hot wing cours black bean rice gyro black bean rice man favorit grill fish shrimp fri calamari rice bean mad forgot chop salad guess n st time like tomorrow thank zeko
# husband threw surpris birthday parti renzo's wonder establish 8 us put us toward end restaur away main restaur nice basic corner william dedic server attent accommod recommend popular malbec wine delici along tasti appet william took care entir group chilean sea bass cook perfect side toston get choos one side entre husband got chimmichurri skirt steak side fri actual yuca fri .... yummi everi one els group great entre well great time thank william take care us definit back
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Frequency-based Vectorization

# %% [markdown]
# ### BoW

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

df_text["clean_text"] = [" ".join(sentence) for sentence in tokenized_filtered_stemmed]

# %%
cv = CountVectorizer()
cv.fit(df_text["clean_text"])
print('number of `tokens`', len(cv.vocabulary_))
cv.vocabulary_
# Out:
# number of `tokens` 18622
# {'ok': 11612,
#  'let': 9627,
#  'start': 15655,
#  'acknowledg': 761,
#  'know': 9291,
#  'stress': 15836,
#  'restaur': 13769,
#  'week': 17978,
#  'server': 14657,
#  'underpaid': 17243,
#  'overwork': 11923,
#  'experi': 6009,
#  'last': 9466,
#  'night': 11307,
#  'absolut': 699,
#  'incred': 8473,
#  'made': 10039,
#  'reserv': 13739,
#  'open': 11704,
#  'tabl': 16184,
#  'clock': 3660,
#  'special': 15436,
#  'offer': 11581,
#  'insid': 8581,
#  'outsid': 11845,
#  'seat': 14539,
#  'opt': 11724,
#  'latter': 9479,
#  'porch': 12784,
#  'set': 14668,
#  'tone': 16757,
#  'wonder': 18234,
#  'think': 16548,
#  'southern': 15375,
#  'wraparound': 18305,
#  'aesthet': 844,
#  'pleas': 12650,
#  'faux': 6193,
#  'ivi': 8772,
#  'wall': 17867,
#  'high': 7940,
#  'top': 16787,
#  'perfect': 12335,
#  'spot': 15531,
#  'afternoon': 874,
#  'cocktail': 3731,
#  'summer': 15988,
#  'wish': 18199,
#  'rememb': 13665,
#  'name': 11107,
#  'excel': 5967,
#  'almost': 1027,
#  'immedi': 8384,
#  'pick': 12479,
#  'drink': 5359,
#  'order': 11745,
#  'queen': 13257,
#  'ann': 1188,
#  'reveng': 13815,
#  'twist': 17106,
#  'old': 11622,
#  'fashion': 6173,
#  'faint': 6102,
#  'heart': 7817,
#  'thank': 16485,
#  'need': 11196,
#  'stiff': 15738,
#  'first': 6393,
#  'cours': 4179,
#  'fri': 6746,
#  'green': 7406,
#  'tomato': 16750,
#  'crushpuppi': 4388,
#  'delici': 4764,
#  'remoulad': 13676,
#  'littl': 9771,
#  'pickl': 12484,
#  'shrimp': 14886,
#  'right': 13888,
#  'yummi': 18495,
#  'sweet': 16124,
#  'savori': 14373,
#  'combin': 3810,
#  'allow': 1019,
#  'butteri': 2775,
#  'cornbread': 4105,
#  'pair': 11988,
#  'realli': 13456,
#  'well': 18006,
#  'crunchi': 4383,
#  'outer': 11827,
#  'shell': 14764,
#  'next': 11273,
#  'second': 14550,
#  'she': 14748,
#  'crab': 4229,
#  'soup': 15366,
#  'watermelon': 17931,
#  'salad': 14220,
#  're': 13436,
#  'accustom': 750,
#  'shore': 14846,
#  'nervou': 11236,
#  'would': 18295,
#  'meet': 10422,
#  'standard': 15636,
#  'exceed': 5965,
#  'expect': 6003,
#  'came': 2905,
#  'hearti': 7822,
#  'overwhelm': 11921,
#  'bowl': 2410,
#  'beauti': 1895,
#  'present': 12929,
#  'amaz': 1074,
#  'juici': 9021,
#  'point': 12712,
#  'rave': 13418,
#  'much': 10982,
#  'want': 17883,
#  'come': 3815,
#  'back': 1638,
#  'even': 5919,
#  'sent': 14627,
#  'group': 7481,
#  'text': 16468,
#  'famili': 6129,
#  'tri': 16935,
#  'place': 12600,
#  'receiv': 13491,
#  'entre': 5790,
#  'knew': 9276,
#  'forward': 6637,
#  'gem': 7027,
#  'citi': 3573,
#  'short': 14848,
#  'rib': 13847,
#  'red': 13541,
#  'snapper': 15203,
#  'bone': 2304,
#  'mouthwat': 10950,
#  'cheesi': 3352,
#  'grit': 7456,
#  'flavor': 6455,
#  'stew': 15730,
#  'ca': 2810,
#  'get': 7077,
#  'better': 2027,
#  'pull': 13161,
#  'spoon': 15524,
#  'okra': 11617,
#  'one': 11663,
#  'favorit': 6199,
#  'bring': 2537,
#  'mani': 10157,
#  'memori': 10465,
#  'grandmoth': 7350,
#  'home': 8048,
#  'cook': 4060,
#  'rare': 13395,
#  'especi': 5859,
#  'find': 6353,
#  'correctli': 4126,
#  'final': 6347,
#  'finish': 6367,
#  'anoth': 1203,
#  'round': 14075,
#  'dessert': 4868,
#  'definit': 4732,
#  'recommend': 13516,
#  'kentucki': 9166,
#  'mule': 11002,
#  'whiskey': 18083,
#  'refresh': 13584,
#  'east': 5513,
#  'bay': 1854,
#  'sour': 15368,
#  'typic': 17122,
#  'donut': 5242,
#  'fan': 6135,
#  'ricotta': 13873,
#  'chang': 3249,
#  'opinion': 11712,
#  'super': 16019,
#  'doughi': 5285,
#  'dens': 4810,
#  'like': 9699,
#  'cake': 2850,
#  'creami': 4288,
#  'kahlua': 9071,
#  'glaze': 7174,
#  'berri': 2005,
#  'spread': 15543,
#  'wow': 18299,
#  'honestli': 8071,
#  'area': 1332,
#  'stop': 15777,
#  'check': 3321,
#  'worth': 18288,
#  'patio': 12185,
#  'awesom': 1590,
#  'servic': 14659,
#  'heather': 7829,
#  'great': 7397,
#  'person': 12368,
#  'good': 7269,
#  'craft': 4240,
#  'beer': 1921,
#  'food': 6571,
#  'uniqu': 17333,
#  'fill': 6332,
#  'downtown': 5305,
#  'st': 15604,
#  'petersburg': 12396,
#  'car': 2986,
#  'charg': 3278,
#  '1000': 26,
#  'air': 921,
#  'condition': 3927,
#  'repair': 13700,
#  'left': 9569,
#  'filter': 6341,
#  'rip': 13905,
#  'intak': 8613,
#  'valv': 17563,
#  'complet': 3872,
#  'extrem': 6061,
#  'racist': 13313,
#  'never': 11252,
#  'return': 13806,
#  'either': 5603,
#  'contact': 4017,
#  'corpor': 4121,
#  'lodg': 9826,
#  'offici': 11586,
#  'complaint': 3868,
#  'new': 11256,
#  'pizza': 12591,
#  'indianapoli': 8491,
#  'hous': 8158,
#  'gluten': 7209,
#  'free': 6709,
#  'crust': 4389,
#  'best': 2014,
#  'hand': 7658,
#  'vibe': 17685,
#  'ice': 8314,
#  'cream': 4284,
#  'purchas': 13186,
#  'meat': 10397,
#  'serv': 14655,
#  'local': 9812,
#  'compani': 3851,
#  'custom': 4481,
#  'knowledg': 9293,
#  'price': 12967,
#  'certainli': 3203,
#  'work': 18264,
#  'residenti': 13746,
#  'commerci': 3833,
#  'industri': 8505,
#  'wreck': 18308,
#  'chees': 3340,
#  'salt': 14248,
#  'sound': 15364,
#  'furthest': 6876,
#  'palett': 12005,
#  'travel': 16907,
#  'thoroughli': 16570,
#  'enjoy': 5763,
#  'ramano': 13357,
#  'rest': 13765,
#  'us': 17496,
#  'disappoint': 5037,
#  'menu': 10477,
#  'cute': 4487,
#  'walk': 17860,
#  'got': 7301,
#  'sat': 14327,
#  'waiter': 17844,
#  'toni': 16763,
#  'gave': 6999,
#  'ton': 16756,
#  'bbq': 1863,
#  'sooo': 15322,
#  'belgian': 1952,
#  'cafe': 2835,
#  'deserv': 4856,
#  'respect': 13759,
#  'prop': 13069,
#  'previou': 12962,
#  'review': 13820,
#  'sunday': 16004,
#  'treat': 16919,
#  'parent': 12094,
#  'mid': 10579,
#  'day': 4621,
#  'lunch': 9965,
#  'splurg': 15509,
#  'numer': 11477,
#  'thing': 16544,
#  'bosch': 2362,
#  'mussel': 11051,
#  'pomm': 12744,
#  'frite': 6775,
#  'chicken': 3396,
#  'smoke': 15177,
#  'turkey': 17068,
#  'steak': 15684,
#  'egg': 5580,
#  'benedict': 1983,
#  'simpli': 14970,
#  'rant': 13385,
#  'past': 12156,
#  'england': 5755,
#  'tast': 16318,
#  'word': 18261,
#  'could': 4159,
#  'describ': 4853,
#  'express': 6038,
#  'face': 6084,
#  'dip': 5019,
#  'sauc': 14344,
#  'tasti': 16324,
#  'alway': 1057,
#  'belgium': 1953,
#  'waffl': 17830,
#  'normal': 11403,
#  'gotten': 7305,
#  'go': 7223,
#  'along': 1031,
#  'time': 16664,
#  'howev': 8173,
#  'make': 10093,
#  'petru': 12403,
#  'age': 884,
#  'pale': 12000,
#  'monk': 10849,
#  'stimul': 15746,
#  'hook': 8084,
#  'three': 16584,
#  'bill': 2085,
#  'bad': 1659,
#  'said': 14207,
#  'kinda': 9229,
#  'pricey': 12974,
#  'total': 16820,
#  'take': 16229,
#  'star': 15644,
#  'wings': 18167,
#  'to': 16714,
#  'year': 18413,
#  'popular': 12780,
#  'franchis': 6675,
#  'feel': 6238,
#  'gone': 7265,
#  'away': 1586,
#  'nice': 11286,
#  'locat': 9815,
#  'probabl': 13018,
#  'ever': 5924,
#  'seen': 14574,
#  '2021': 223,
#  'jeep': 8875,
#  'grand': 7341,
#  'cheroke': 3367,
#  'loredo': 9877,
#  'satisfi': 14336,
#  'schedul': 14424,
#  'appoint': 1286,
#  'onlin': 11673,
#  'lindsay': 9733,
#  'dattilio': 4607,
#  'abl': 678,
#  'exactli': 5957,
#  'friendli': 6754,
#  'provid': 13111,
#  'staff': 15613,
#  'refer': 13570,
#  'friend': 6752,
#  'extra': 6053,
#  'fanci': 6137,
#  'gnocchi': 7219,
#  'huge': 8205,
#  'prepar': 12921,
#  'pasta': 12157,
#  'product': 13039,
#  'hope': 8096,
#  'philli': 12434,
#  'manag': 10127,
#  'list': 9757,
#  'seriou': 14650,
#  'devote': 4903,
#  'qualiti': 13241,
#  'exquisit': 6040,
#  'thought': 16574,
#  'perfectli': 12337,
#  'execut': 5985,
#  'happi': 7701,
#  'around': 1369,
#  'grab': 7319,
#  'sceneri': 14419,
#  'armatur': 1355,
#  'folk': 6558,
#  'bite': 2130,
#  'somewher': 15306,
#  'head': 7793,
#  'watch': 17922,
#  'game': 6932,
#  'sport': 15526,
#  'bar': 1757,
#  'pub': 13133,
#  'slam': 15072,
#  'across': 771,
#  'joint': 8959,
#  'glanc': 7166,
#  'seem': 14572,
#  'pretti': 12951,
#  'catch': 3109,
#  'although': 1049,
#  'lack': 9379,
#  'larg': 9451,
#  'big': 2071,
#  'screen': 14490,
#  'tv': 17092,
#  'plenti': 12662,
#  'medium': 10418,
#  'size': 15020,
#  'scatter': 14415,
#  'also': 1044,
#  'notic': 11435,
#  'redskin': 13556,
#  'flag': 6423,
#  'may': 10330,
#  'select': 14591,
#  'tablet': 16190,
#  'scroll': 14497,
#  'current': 4463,
#  'read': 13444,
#  'detail': 4875,
#  'settl': 14670,
#  'soft': 15265,
#  'parad': 12072,
#  'flagship': 6425,
#  'fruit': 6807,
#  'ale': 971,
#  'found': 6644,
#  'later': 9471,
#  'hour': 8155,
#  'woo': 18242,
#  'hoo': 8080,
#  'ampl': 1127,
#  'husband': 8255,
#  'patti': 12197,
#  'melt': 10451,
#  'potato': 12833,
#  'wing': 18165,
#  'cup': 4439,
#  'onion': 11668,
#  'dish': 5091,
#  'mild': 10615,
#  'spici': 15474,
#  've': 17593,
#  'taken': 16231,
#  'chanc': 3246,
#  'smoki': 15180,
#  'wait': 17843,
#  'long': 9844,
#  '20': 200,
#  '30': 299,
#  'minut': 10671,
#  'half': 7630,
#  'full': 6838,
#  'neg': 11204,
#  'experienc': 6010,
#  'understaf': 17250,
#  'appl': 1276,
#  'fresh': 6736,
#  'kitchen': 9252,
#  'till': 16659,
#  'eat': 5519,
#  'neighborhood': 11214,
#  'non': 11373,
#  'smok': 15176,
#  'line': 9735,
#  'monday': 10835,
#  'noon': 11389,
#  'outdoor': 11825,
#  'terrif': 16451,
#  'autumn': 1559,
#  'wint': 18178,
#  'season': 14535,
#  'hot': 8137,
#  'platter': 12635,
#  'today': 16724,
#  'sandwich': 14290,
#  'love': 9912,
#  'ride': 13878,
#  'igor': 8350,
#  'world': 18279,
#  'ten': 16410,
#  'sinc': 14976,
#  'heydey': 7920,
#  '90': 610,
#  'still': 15742,
#  'hang': 7679,
#  'anytim': 1241,
#  'problem': 13024,
#  'insist': 8585,
#  'dri': 5351,
#  'burger': 2719,
#  'ask': 1430,
#  'refus': 13593,
#  'sure': 16051,
#  'push': 13202,
#  'beef': 1914,
#  'spatula': 15421,
#  'known': 9294,
#  'worldwid': 18280,
#  'anyth': 1240,
#  'mean': 10388,
#  'goe': 7243,
#  'worri': 18283,
#  'might': 10597,
#  'usda': 17502,
#  'ron': 14022,
#  'jeremi': 8898,
#  'blush': 2245,
#  'ps': 13123,
#  'miss': 10713,
#  'bartend': 1807,
#  'part': 12120,
#  'jimmi': 8932,
#  'kelli': 9149,
#  'waitstaff': 17850,
#  'recent': 13492,
#  'visit': 17756,
#  'kind': 9228,
#  'help': 7872,
#  'yet': 18440,
#  'meal': 10384,
#  'use': 17503,
#  'salesman': 14236,
#  'encourag': 5734,
#  'everyon': 5936,
#  'upgrad': 17452,
#  'portion': 12804,
#  'add': 789,
#  'wine': 18162,
#  'bottl': 2376,
#  'glass': 7170,
#  'term': 16438,
#  'hoss': 8132,
#  'process': 13029,
#  'tip': 16688,
#  'shock': 14827,
#  'profession': 13043,
#  'fight': 6318,
#  'uphil': 17454,
#  'battl': 1846,
#  'nashvil': 11133,
#  'erod': 5834,
#  'oldschool': 11626,
#  'attent': 1508,
#  'switch': 16152,
#  'entir': 5784,
#  'differ': 4964,
#  'cut': 4486,
#  'downright': 5301,
#  'insult': 8609,
#  'contend': 4025,
#  'preoccupi': 12916,
#  'pay': 12208,
#  'steakhous': 15685,
#  'must': 11054,
#  'uber': 17130,
#  'driver': 5369,
#  'beignet': 1945,
#  'cheddar': 3332,
#  'sammich': 14271,
#  'app': 1264,
#  'strawberri': 15820,
#  'jelli': 8881,
#  'omg': 11647,
#  'shout': 14866,
#  'skyler': 15063,
#  'least': 9549,
#  'young': 18468,
#  'kid': 9203,
#  'laid': 9405,
#  'adult': 828,
#  'play': 12637,
#  'etc': 5883,
#  'courtsid': 4191,
#  'grill': 7441,
#  'ago': 895,
#  'hire': 7983,
#  'consult': 4013,
#  'pro': 13014,
#  'cold': 3765,
#  'oh': 11598,
#  'brother': 2594,
#  'jar': 8840,
#  'avoid': 1578,
#  'bread': 2468,
#  'co': 3703,
#  'worker': 18269,
#  'paid': 11978,
#  'enough': 5769,
#  'job': 8942,
#  'done': 5234,
#  'understand': 17251,
#  'leav': 9551,
#  'utensil': 17516,
#  'dress': 5345,
#  'guess': 7525,
#  'up': 17440,
#  'bs': 2627,
#  'medspa': 10419,
#  'dermatologist': 4845,
#  'skin': 15049,
#  'issu': 8746,
#  'instead': 8597,
#  'call': 2881,
#  'coolsculpt': 4074,
#  'botox': 2375,
#  'patient': 12182,
#  'yearli': 18414,
#  'florida': 6503,
#  'ph': 12411,
#  'dermatolog': 4844,
#  'tacki': 16196,
#  'peopl': 12304,
#  'look': 9857,
#  'societi': 15256,
#  'disgust': 5089,
#  'saw': 14376,
#  'doctor': 5187,
#  'quit': 13291,
#  'joke': 8961,
#  'actual': 779,
#  'voicemail': 17773,
#  'tell': 16397,
#  'proof': 13067,
#  'consist': 3999,
#  'breakfast': 2477,
#  'lynn': 9995,
#  'waitress': 17849,
#  'usual': 17510,
#  'stuff': 15881,
#  'quickli': 13278,
#  'convers': 4047,
#  'bright': 2526,
#  'close': 3668,
#  'trolley': 16976,
#  'peac': 12232,
#  'maker': 10095,
#  'po': 12697,
#  'boy': 2414,
#  'gumbo': 7557,
#  '14': 92,
#  'fall': 6119,
#  'piec': 12499,
#  'alon': 1030,
#  'roast': 13953,
#  'figur': 6320,
#  'mix': 10741,
#  'mask': 10279,
#  'ye': 18407,
#  'mainli': 10077,
#  'sausag': 14358,
#  'mine': 10649,
#  'rice': 13855,
#  'veggi': 17607,
#  'combo': 3812,
#  'featur': 6221,
#  'netflix': 11240,
#  'show': 14870,
#  'overal': 11858,
#  'solid': 15286,
#  'introduc': 8663,
#  'nola': 11368,
#  'whim': 18073,
#  'busi': 2747,
#  'sit': 15005,
#  'appet': 1273,
#  'decid': 4685,
#  'stay': 15677,
#  'dinner': 5013,
#  'amber': 1082,
#  'impress': 8414,
#  'less': 9620,
#  '100': 25,
#  'johnni': 8954,
#  'la': 9363,
#  'cucina': 4417,
#  'sister': 15004,
#  'highli': 7945,
#  'lynzi': 9996,
#  'resourc': 13758,
#  'hospit': 8130,
#  'birth': 2110,
#  'daughter': 4610,
#  'born': 2356,
#  'june': 9041,
#  'outstand': 11847,
#  'valu': 17561,
#  'reason': 13467,
#  'fee': 6232,
#  'two': 17111,
#  'session': 14667,
#  'commit': 3836,
#  'fulli': 6841,
#  'put': 13209,
#  'togeth': 16734,
#  'binder': 2098,
#  'inform': 8536,
#  'straightforward': 15800,
#  'option': 11729,
#  'includ': 8453,
#  'tool': 16774,
#  'comfort': 3821,
#  'measur': 10395,
#  'labor': 9374,
#  'choic': 3476,
#  'pregnanc': 12904,
#  'video': 17704,
#  'regularli': 13614,
#  'bravo': 2465,
#  'sale': 14230,
#  'someon': 15299,
#  'say': 14381,
#  'medic': 10410,
#  'field': 6308,
#  'support': 16042,
#  'shown': 14878,
#  'sell': 14600,
#  'via': 17682,
#  'upsal': 17469,
#  'bag': 1670,
#  'fail': 6100,
#  'type': 17121,
#  'teenag': 16385,
#  'everi': 5927,
#  'build': 2666,
#  'fire': 6375,
#  'god': 7236,
#  'sake': 14215,
#  'happen': 7697,
#  'forget': 6607,
#  '15': 105,
#  '00': 0,
#  'buck': 2640,
#  'ben': 1974,
#  'bud': 2646,
#  'heavier': 7834,
#  'forc': 6592,
#  'will': 18138,
#  'shake': 14698,
#  'grate': 7369,
#  'heaven': 7831,
#  'chili': 3418,
#  'dog': 5194,
#  'drown': 5379,
#  'ambianc': 1084,
#  'appropri': 1294,
#  'music': 11045,
#  'cool': 4070,
#  'fast': 6174,
#  'self': 14594,
#  'fountain': 6648,
#  'trust': 17008,
#  'ketchup': 9177,
#  'pump': 13167,
#  'napkin': 11117,
#  'dispens': 5116,
#  'ah': 903,
#  'carv': 3073,
#  'pocket': 12703,
#  'knife': 9278,
#  'cant': 2954,
#  'possibl': 12822,
#  'complain': 3867,
#  'westbank': 18024,
#  'see': 14566,
#  'brah': 2435,
#  'prime': 12988,
#  'consid': 3996,
#  'orlean': 11772,
#  'without': 18211,
#  'randomli': 13378,
#  'stumbl': 15884,
#  'upon': 17464,
#  'glad': 7159,
#  'futur': 6886,
#  'matter': 10314,
#  'side': 14923,
#  'town': 16842,
#  'tough': 16824,
#  'situat': 15012,
#  'john': 8952,
#  'pace': 11952,
#  'roof': 14026,
#  'guy': 7573,
#  'quick': 13274,
#  'small': 15142,
#  'lot': 9887,
#  'anyon': 1238,
#  'seek': 14571,
#  'asian': 1426,
#  'space': 15391,
#  'sad': 14183,
#  'move': 10952,
#  'smaller': 15143,
#  'origin': 11767,
#  'noth': 11432,
#  'pleasant': 12651,
#  'style': 15897,
#  'bento': 1993,
#  'box': 2412,
#  'clear': 3630,
#  'took': 16773,
#  'refil': 13575,
#  'crowd': 4366,
#  'oyster': 11941,
#  '12': 59,
#  'raw': 13423,
#  'shuck': 14894,
#  'welcom': 18002,
#  'char': 3264,
#  'broil': 2571,
#  'life': 9677,
#  'alright': 1042,
#  'll': 9791,
#  'chedda': 3331,
#  'izzi': 8776,
#  'entertain': 5780,
#  'fun': 6846,
#  'chines': 3439,
#  'girl': 7141,
#  'amazingli': 1078,
#  'ahead': 905,
#  'wife': 18122,
#  'birthday': 2111,
#  'atmospher': 1488,
#  'trendi': 16928,
#  'horribl': 8113,
#  'lobster': 9808,
#  'bisqu': 2118,
#  'fact': 6091,
#  'chowder': 3501,
#  'chunk': 3529,
#  'none': 11376,
#  'swallow': 16099,
#  'asid': 1428,
#  'imposs': 8413,
#  'flake': 6427,
#  'fork': 6613,
#  'soon': 15320,
#  'earlier': 5495,
#  'whole': 18097,
#  'ur': 17482,
#  'truli': 17004,
#  'interact': 8620,
#  'brais': 2440,
#  'delect': 4757,
#  'pork': 12787,
#  'chop': 3485,
#  'brussel': 2620,
#  'sprout': 15559,
#  'end': 5736,
#  'pecan': 12246,
#  'pie': 12498,
#  'goodness': 7273,
#  'biscuit': 2114,
#  'basket': 1823,
#  'excit': 5974,
#  'owner': 11928,
#  'expand': 6001,
#  'replenish': 13712,
#  'replac': 13711,
#  'rebuild': 13482,
#  'revamp': 13812,
#  'setup': 14672,
#  'situ': 15011,
#  'shop': 14839,
#  'gold': 7252,
#  'mod': 10781,
#  'rock': 13974,
#  'million': 10634,
#  'surprisingli': 16067,
#  'ramen': 13362,
#  'spam': 15402,
#  'bun': 2698,
#  'shoyu': 14882,
#  'kimchi': 9224,
#  'far': 6153,
#  'authent': 1547,
#  'tucson': 17035,
#  'sushi': 16076,
#  'jason': 8844,
#  'beau': 1892,
#  'orient': 11765,
#  'met': 10514,
#  'accident': 730,
#  'discov': 5068,
#  'ventur': 17628,
#  'pat': 12170,
#  'rather': 13409,
#  'unfulfil': 17307,
#  'mood': 10881,
#  'number': 11476,
#  'slice': 15093,
#  'coke': 3761,
#  '50': 429,
#  'mediocr': 10414,
#  'meh': 10430,
#  'dine': 5003,
#  'noisi': 11366,
#  'save': 14368,
#  'grace': 7320,
#  'bois': 2286,
#  'brew': 2497,
#  'sockey': 15260,
#  'reboot': 13480,
#  'jennif': 8892,
#  'hagemey': 7606,
#  'frustrat': 6813,
#  'insur': 8610,
#  'agent': 888,
#  'polici': 12731,
#  'hit': 7994,
#  'renew': 13683,
#  'coverag': 4202,
#  'comput': 3894,
#  'tremend': 16925,
#  'amount': 1123,
#  'footwork': 6586,
#  'fix': 6411,
#  'twice': 17100,
#  'inconveni': 8465,
#  'initi': 8551,
#  'quot': 13296,
#  'auto': 1549,
#  'homeown': 8056,
#  'umbrella': 17161,
#  'lower': 9921,
#  'went': 18014,
#  'institut': 8600,
#  'payment': 12212,
#  'keep': 9139,
#  'deduct': 4703,
#  'hurrican': 8251,
#  'meant': 10392,
#  'longer': 9845,
#  'minor': 10664,
#  'offic': 11584,
#  'told': 16743,
#  'eight': 5595,
#  'month': 10873,
#  'caus': 3127,
#  'carrier': 3057,
#  'seibert': 14581,
#  'broker': 2575,
#  'particular': 12128,
#  'suspect': 16079,
#  'beyond': 2043,
#  'transit': 16890,
#  'easier': 5510,
#  'cost': 4144,
#  '550': 461,
#  'higher': 7943,
#  'limit': 9717,
#  'comprehens': 3889,
#  'greater': 7398,
#  'dark': 4589,
#  'smokey': 15179,
#  'mall': 10111,
#  'carpet': 3049,
#  'quarter': 13250,
#  '1987': 180,
#  'down': 5291,
#  'store': 15784,
#  'woolworth': 18256,
#  'strawbridg': 15823,
#  'clothier': 3676,
#  'sam': 14262,
#  'goodi': 7271,
#  'suncoast': 16002,
#  'movi': 10957,
#  'book': 2326,
#  'walden': 17857,
#  'departur': 4823,
#  'structur': 15869,
#  'kb': 9129,
#  'toy': 16851,
#  'king': 9234,
#  'gap': 6948,
#  'hard': 7710,
#  'believ': 1956,
#  ...}

# %%
import pandas as pd
df_word_freq = pd.DataFrame(sorted_word_freq, columns=['word', 'frequency'])
df_word_freq_sorted = df_word_freq.sort_values(by='frequency', ascending=False)
print(df_word_freq_sorted.head(10))
# Out:
#      word  frequency
# 0    food       5292
# 1   place       5068
# 2    good       4809
# 3   great       4482
# 4    time       4000
# 5      go       3699
# 6     get       3654
# 7   order       3613
# 8    like       3478
# 9  servic       3380

# %% [markdown]
# ## Filtering for a specific type of business

# %%
business['categories'].unique()
# Out:
# array(['Doctors, Traditional Chinese Medicine, Naturopathic/Holistic, Acupuncture, Health & Medical, Nutritionists',
#        'Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services',
#        'Department Stores, Shopping, Fashion, Home & Garden, Electronics, Furniture Stores',
#        ...,
#        'Shopping, Jewelry, Piercing, Toy Stores, Beauty & Spas, Accessories, Fashion',
#        'Fitness/Exercise Equipment, Eyewear & Opticians, Shopping, Sporting Goods, Bikes',
#        'Beauty & Spas, Permanent Makeup, Piercing, Tattoo'], dtype=object)

# %%
cafes = business[business['categories'].str.contains('Cafes', case = False, na = False)]

# %%
cafes
# Out:
#                    business_id                             name  \
# 20      WKMJwqnfZKsAae75RMP6jA   Roast Coffeehouse and Wine Bar
# 46      JX4tUpd09YFchLBuI43lGw  Naked Cyber Cafe & Espresso Bar
# 47      lk9IwjZXqUMqqOhM774DtQ                 Caviar & Bananas
# 53      cVBxfMC4lp3DnocjYA3FHQ                Paws The Cat Cafe
# 99      1MeIwdbTnZOBFCKOrgaxuw           Ricardo's Italian Cafe
# ...                        ...                              ...
# 150232  Scd-rcsQCn60t1sHHFv-og                      First Watch
# 150261  Y0TWCjiiXlFi2XO2cFrUzQ                 Connexxions Cafe
# 150269  2dVJ7R-3JMmu2v4DJYtBbw               Spring Mount Hotel
# 150271  BIyT7Kr7tMJqlfp4oOOYQg                 Copper Bell Cafe
# 150327  cM6V90ExQD6KMSU3rRB5ZA                Dutch Bros Coffee
#
#                             address            city state postal_code  \
# 20              10359 104 Street NW        Edmonton    AB     T5J 1B9
# 46             10303  108 Street NW        Edmonton    AB     T5J 1L7
# 47                    2031 Broadway       Nashville    TN       37203
# 53                 10588 109 Street        Edmonton    AB     T5H 3B2
# 99                    1931 Park Ave     Saint Louis    MO       63104
# ...                             ...             ...   ...         ...
# 150232  4045 N Tyrone Blvd, Ste 204  St. Petersburg    FL       33709
# 150261          12644 137 Avenue NW        Edmonton    AB     T5L 4Y5
# 150269                    3 Main St   Schwenksville    PA       19473
# 150271             11228 Boyette Rd       Riverview    FL       33569
# 150327          1181 N Milwaukee St           Boise    ID       83704
#
#          latitude   longitude  stars  review_count  is_open  \
# 20      53.546045 -113.499169    4.0            40        0
# 46      53.544682 -113.506589    4.0            12        1
# 47      36.148371  -86.798895    3.5           159        0
# 53      53.549633 -113.508780    5.0            20        0
# 99      38.617272  -90.212784    3.5            80        0
# ...           ...         ...    ...           ...      ...
# 150232  27.808314  -82.752110    3.5           183        1
# 150261  53.600573 -113.540273    4.5            13        0
# 150269  40.275532  -75.456772    2.0             5        1
# 150271  27.853745  -82.316887    3.5            49        0
# 150327  43.615401 -116.284689    4.0            33        1
#
#                                                attributes  \
# 20      {'AcceptsInsurance': None, 'AgesAllowed': None...
# 46      {'AcceptsInsurance': None, 'AgesAllowed': None...
# 47      {'AcceptsInsurance': None, 'AgesAllowed': None...
# 53      {'AcceptsInsurance': None, 'AgesAllowed': None...
# 99      {'AcceptsInsurance': None, 'AgesAllowed': None...
# ...                                                   ...
# 150232  {'AcceptsInsurance': None, 'AgesAllowed': None...
# 150261  {'AcceptsInsurance': None, 'AgesAllowed': None...
# 150269  {'AcceptsInsurance': None, 'AgesAllowed': None...
# 150271  {'AcceptsInsurance': None, 'AgesAllowed': None...
# 150327  {'AcceptsInsurance': None, 'AgesAllowed': None...
#
#                                                categories  \
# 20      Coffee & Tea, Food, Cafes, Bars, Wine Bars, Re...
# 46      Arts & Entertainment, Music Venues, Internet S...
# 47      Coffee & Tea, Restaurants, Wine Bars, Bars, Ni...
# 53      Coffee & Tea, Cafes, Pets, Restaurants, Pet Ad...
# 99      American (New), Restaurants, Cafes, Italian, A...
# ...                                                   ...
# 150232  Cafes, Restaurants, Breakfast & Brunch, Americ...
# 150261  Hobby Shops, Tabletop Games, Coffee & Tea, Foo...
# 150269  Nightlife, Cafes, Hotels, Bars, Hotels & Trave...
# 150271             Breakfast & Brunch, Cafes, Restaurants
# 150327  Cafes, Juice Bars & Smoothies, Coffee & Tea, R...
#
#                                                     hours
# 20      {'Friday': '8:0-18:0', 'Monday': '8:0-18:0', '...
# 46      {'Friday': '11:0-1:0', 'Monday': '11:0-1:0', '...
# 47      {'Friday': '7:0-17:0', 'Monday': '7:0-17:0', '...
# 53      {'Friday': '10:0-20:0', 'Monday': '0:0-0:0', '...
# 99      {'Friday': '16:0-22:0', 'Monday': '11:0-14:0',...
# ...                                                   ...
# 150232  {'Friday': '7:0-14:30', 'Monday': '0:0-0:0', '...
# 150261                                               None
# 150269  {'Friday': '11:0-2:0', 'Monday': '11:0-0:0', '...
# 150271  {'Friday': '7:30-14:30', 'Monday': '7:30-14:30...
# 150327  {'Friday': '0:0-0:0', 'Monday': '0:0-0:0', 'Sa...
#
# [2859 rows x 14 columns]

# %%
merged_df['cafe_review'] = merged_df["business_id"].isin(cafes['business_id'])

# %%
cafe_reviews = merged_df[merged_df["cafe_review"]==True]

# %%
cafe_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 294728 entries, 11 to 6989545
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   review_id      294728 non-null  object
#  1   business_id    294728 non-null  object
#  2   user_id        294728 non-null  object
#  3   stars          294728 non-null  int64
#  4   text           294728 non-null  object
#  5   date           294728 non-null  datetime64[ns]
#  6   name           294727 non-null  object
#  7   review_count   294727 non-null  float64
#  8   yelping_since  294727 non-null  object
#  9   cafe_review    294728 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 22.8+ MB

# %%
cafe_reviews['text']
# Out:
# 11         Locals recommended Milktooth, and it's an amaz...
# 19         My absolute favorite cafe in the city. Their b...
# 30         First time there and it was excellent!!! It fe...
# 43         Stopped by after a Sunday morning walk in the ...
# 44         In a word... "OVERRATED!".  The food took fore...
#                                  ...
# 6989508    I am surprised by the recent negative reviews....
# 6989513    The pastries are made in house so I cannot wai...
# 6989522    Eh.  It was just ok.  While visiting Tampa som...
# 6989525    Fiddlehead Fern Cafe keeps getting better and ...
# 6989545    Please come hungry!!!! Every time I've been in...
# Name: text, Length: 294728, dtype: object

# %%
cr_text = pd.DataFrame(cafe_reviews.text.str.lower())
cr_text
# Out:
#                                                       text
# 11       locals recommended milktooth, and it's an amaz...
# 19       my absolute favorite cafe in the city. their b...
# 30       first time there and it was excellent!!! it fe...
# 43       stopped by after a sunday morning walk in the ...
# 44       in a word... "overrated!".  the food took fore...
# ...                                                    ...
# 6989508  i am surprised by the recent negative reviews....
# 6989513  the pastries are made in house so i cannot wai...
# 6989522  eh.  it was just ok.  while visiting tampa som...
# 6989525  fiddlehead fern cafe keeps getting better and ...
# 6989545  please come hungry!!!! every time i've been in...
#
# [294728 rows x 1 columns]

# %%
casual_tknzr = TweetTokenizer(reduce_len=True)
cafe_tokenized = [casual_tknzr.tokenize(t) for t in cr_text['text']] 
cafe_tokenized[0]
# Out:
# ['locals',
#  'recommended',
#  'milktooth',
#  ',',
#  'and',
#  "it's",
#  'an',
#  'amazing',
#  'jewel',
#  'of',
#  'indianapolis',
#  '.',
#  "i'm",
#  'glade',
#  'i',
#  'had',
#  'the',
#  'chance',
#  'to',
#  'experience',
#  'this',
#  '.']

# %%
english_words = set(words.words())
stop_words = set(stopwords.words('english'))
#punctuations = set(string.punctuation) Interested in removing these to see if it helps. if not, paste -> into list comprehension. ||| and word not in punctuations
cafe_txt_filtered = [[word for word in sentence if word.lower() not in stop_words and word.lower() in english_words] for sentence in cafe_tokenized]

print(cafe_txt_filtered[1])
# Out:
# ['absolute', 'favorite', 'city', 'black', 'white', 'probably', 'best', 'ever', 'sweet', 'right', 'amount', 'foam', 'always', 'really', 'good', 'even', 'people', 'lot', 'space', 'work', 'noise', 'level', 'perfect', 'music', 'perfect', 'level', 'always', 'enjoy', 'bring', 'dogs', 'keep', 'giving', 'business', 'long']

# %%
cr_text["clean_text"] = [" ".join(sentence) for sentence in cafe_txt_filtered]
cv = CountVectorizer()
t = cv.fit_transform(cr_text["clean_text"])

# %%
freq_array = t.sum(axis=0).A1
cafe_token_freq = pd.DataFrame({"token": cv.get_feature_names_out(), 'freq_count': freq_array})

# %%
cafe_token_freq.sort_values(by='freq_count', ascending=False)
# Out:
#             token  freq_count
# 8264         food      183271
# 15625       place      158567
# 9115         good      151256
# 9281        great      139714
# 3917       coffee      101556
# ...           ...         ...
# 8164     flossing           1
# 2172    bluntness           1
# 2173         blup           1
# 20689        stum           1
# 18090  rustically           1
#
# [24730 rows x 2 columns]
